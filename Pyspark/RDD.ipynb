# %%
import pyspark
from pyspark import SparkConf, SparkContext
conf=SparkConf().setAppName("Read File")
sc=SparkContext.getOrCreate(conf=conf)

# %%
rdd= sc.textFile("/FileStore/tables/Sample3-2.txt")

# %%
rdd.collect()
# Out:
# Out[12]: ['1 2 3 4 5 6', '6 5 4 3 2', '6 5 4 3 2', '23 ', '23 ', '23', '45 677 89']

# %%
rdd1=rdd.map(lambda x: x.split(' '))
rdd1.collect()
# Out:
# Out[13]: [['1', '2', '3', '4', '5', '6'],
#  ['6', '5', '4', '3', '2'],
#  ['6', '5', '4', '3', '2'],
#  ['23', ''],
#  ['23', ''],
#  ['23'],
#  ['45', '677', '89']]

# %%
def foo(x):
   return x.split(' ')

# %%
rdd2= rdd.map(foo)
rdd2.collect()
# Out:
# Out[15]: [['1', '2', '3', '4', '5', '6'],
#  ['6', '5', '4', '3', '2'],
#  ['6', '5', '4', '3', '2'],
#  ['23', ''],
#  ['23', ''],
#  ['23'],
#  ['45', '677', '89']]

# %%
def foo(x):
    if x=='23 ':
        return False
    else:
        return True

# %%
rdd7 = rdd.filter(foo)
rdd7.collect()
# Out:
# Out[17]: ['1 2 3 4 5 6', '6 5 4 3 2', '6 5 4 3 2', '23', '45 677 89']

# %%
rdd1=rdd.filter(foo)

# %%
rdd1.collect()
# Out:
# Out[19]: ['1 2 3 4 5 6', '6 5 4 3 2', '6 5 4 3 2', '23', '45 677 89']

# %%
rdd3 = sc.textFile("/FileStore/tables/sample.txt")

# %%
rdd3.collect()
# Out:
# Out[21]: ['Hi how are you?', 'Hope you are doing ', 'great']

# %%
rdd4=rdd3.flatMap(lambda x: x.split(' '))

# %%
rdd5=rdd4.map(lambda x: (x,len(x)))
rdd5.collect()
# Out:
# Out[23]: [('Hi', 2),
#  ('how', 3),
#  ('are', 3),
#  ('you?', 4),
#  ('Hope', 4),
#  ('you', 3),
#  ('are', 3),
#  ('doing', 5),
#  ('', 0),
#  ('great', 5)]

# %%
rdd5.groupByKey().mapValues(list).collect()
# Out:
# Out[24]: [('Hi', [2]),
#  ('are', [3, 3]),
#  ('you?', [4]),
#  ('', [0]),
#  ('how', [3]),
#  ('Hope', [4]),
#  ('you', [3]),
#  ('doing', [5]),
#  ('great', [5])]

# %%
def len1(x):
    l=x.split(' ')
    l2=[]
    for s in l:
        l2.append(len(s))
    return l2

# %%
rdd4 = rdd3.map(len1)

# %%
rdd4.collect()
# Out:
# Out[27]: [[2, 3, 3, 4], [4, 3, 3, 5, 0], [5]]

# %%
rdd5= rdd3.map(lambda x:[len(s) for s in x.split(' ')])

# %%
rdd5.collect()
# Out:
# Out[29]: [[2, 3, 3, 4], [4, 3, 3, 5, 0], [5]]

# %%
rdd6 = rdd.flatMap(lambda x: x.split(" "))
rdd6.collect()
# Out:
# Out[30]: ['1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '23',
#  '',
#  '23',
#  '',
#  '23',
#  '45',
#  '677',
#  '89']

# %%
rdd6.count()
# Out:
# Out[47]: 24

# %%
rdd6.countByValue()
# Out:
# Out[48]: defaultdict(int,
#             {'1': 1,
#              '2': 3,
#              '3': 3,
#              '4': 3,
#              '5': 3,
#              '6': 3,
#              '23': 3,
#              '': 2,
#              '45': 1,
#              '677': 1,
#              '89': 1})

# %%
rdd8 = sc.textFile('/FileStore/tables/1.txt')

# %%
rdd8.collect()
# Out:
# Out[32]: ['This animal company mango', 'ant dog monkey cat ', 'carrot ']

# %%
rdd8.flatMap(lambda x: x.split(" ")).map(lambda x : (x,1)).reduceByKey(lambda x ,y : x+y).collect()
# Out:
# Out[45]: [('mango', 1),
#  ('ant', 1),
#  ('cat', 1),
#  ('', 2),
#  ('carrot', 1),
#  ('This', 1),
#  ('animal', 1),
#  ('company', 1),
#  ('dog', 1),
#  ('monkey', 1)]

# %%
def remove(x):
    if (x.startswith('a') or x.startswith('c')):
        return False
    else:
        return True

# %%
rdd10=rdd9.filter(remove)
rdd10.collect()
# Out:
# Out[35]: ['This', 'mango', 'dog', 'monkey', '', '']

# %%
rdd11= rdd9.filter(lambda x: not(x.startswith('a') or x.startswith('c')))
rdd11.collect()
# Out:
# Out[36]: ['This', 'mango', 'dog', 'monkey', '', '']

# %%
rdd1=rdd.flatMap(lambda x: x.split(" ")).distinct()

# %%
rdd1.collect()
# Out:
# Out[41]: ['1', '4', '', '45', '677', '2', '3', '5', '6', '23', '89']

# %%
rdd.collect()
# Out:
# Out[42]: ['1 2 3 4 5 6', '6 5 4 3 2', '6 5 4 3 2', '23 ', '23 ', '23', '45 677 89']

# %%
rdd.flatMap(lambda x: x.split(' ')).map(lambda x:(x,1)).reduceByKey(lambda x,y : x+y).collect()
# Out:
# Out[43]: [('1', 1),
#  ('4', 3),
#  ('', 2),
#  ('45', 1),
#  ('677', 1),
#  ('2', 3),
#  ('3', 3),
#  ('5', 3),
#  ('6', 3),
#  ('23', 3),
#  ('89', 1)]

# %%
rdd= sc.textFile('/FileStore/tables/average_quiz_sample.csv')

# %%
rdd.collect()
# Out:
# Out[50]: ['JAN,NY,3.0',
#  'JAN,PA,1.0',
#  'JAN,NJ,2.0',
#  'JAN,CT,4.0',
#  'FEB,PA,1.0',
#  'FEB,NJ,1.0',
#  'FEB,NY,2.0',
#  'FEB,VT,1.0',
#  'MAR,NJ,2.0',
#  'MAR,NY,1.0',
#  'MAR,VT,2.0',
#  'MAR,PA,3.0']

# %%
rdd2=rdd.map(lambda x : (x.split(',')[0] ,(float(x.split(',')[2]) , 1)))

# %%
rdd2.collect()
# Out:
# Out[56]: [('JAN', (3.0, 1)),
#  ('JAN', (1.0, 1)),
#  ('JAN', (2.0, 1)),
#  ('JAN', (4.0, 1)),
#  ('FEB', (1.0, 1)),
#  ('FEB', (1.0, 1)),
#  ('FEB', (2.0, 1)),
#  ('FEB', (1.0, 1)),
#  ('MAR', (2.0, 1)),
#  ('MAR', (1.0, 1)),
#  ('MAR', (2.0, 1)),
#  ('MAR', (3.0, 1))]

# %%
rdd3=rdd2.reduceByKey(lambda x,y : (x[0]+y[0] , x[1]+y[1]))

# %%
rdd3.collect()
# Out:
# Out[58]: [('JAN', (10.0, 4)), ('FEB', (5.0, 4)), ('MAR', (8.0, 4))]

# %%
rdd3.map(lambda x : (x[0] ,x[1][0]/x[1][1])).collect()
# Out:
# Out[61]: [('JAN', 2.5), ('FEB', 1.25), ('MAR', 2.0)]

# %%
rdd= sc.textFile('/FileStore/tables/movie_ratings.csv')
rdd.collect()
# Out:
# Out[63]: ['The Shawshank Redemption,3',
#  'The Matrix,5',
#  '12 Angry Men,3',
#  '12 Angry Men,4',
#  'The Matrix,5',
#  'Pulp Fiction,4',
#  'The Godfather,5',
#  'The Shawshank Redemption,2',
#  'Pulp Fiction,4',
#  'The Godfather,5',
#  '12 Angry Men,2',
#  'The Godfather,3',
#  'Pulp Fiction,4',
#  '12 Angry Men,1',
#  'The Shawshank Redemption,2',
#  '12 Angry Men,1',
#  'The Shawshank Redemption,5',
#  'Pulp Fiction,5',
#  'Pulp Fiction,2',
#  'The Matrix,4']

# %%
rdd2=rdd.map(lambda x : (x.split(',')[0] , int(x.split(',')[1])))
rdd2.collect()
# Out:
# Out[65]: [('The Shawshank Redemption', 3),
#  ('The Matrix', 5),
#  ('12 Angry Men', 3),
#  ('12 Angry Men', 4),
#  ('The Matrix', 5),
#  ('Pulp Fiction', 4),
#  ('The Godfather', 5),
#  ('The Shawshank Redemption', 2),
#  ('Pulp Fiction', 4),
#  ('The Godfather', 5),
#  ('12 Angry Men', 2),
#  ('The Godfather', 3),
#  ('Pulp Fiction', 4),
#  ('12 Angry Men', 1),
#  ('The Shawshank Redemption', 2),
#  ('12 Angry Men', 1),
#  ('The Shawshank Redemption', 5),
#  ('Pulp Fiction', 5),
#  ('Pulp Fiction', 2),
#  ('The Matrix', 4)]

# %%
rdd2.reduceByKey(lambda x , y : x if x<y else y ).collect()
# Out:
# Out[66]: [('The Shawshank Redemption', 2),
#  ('12 Angry Men', 1),
#  ('The Godfather', 3),
#  ('The Matrix', 4),
#  ('Pulp Fiction', 2)]

# %%
rdd2.reduceByKey(lambda x , y : x if x>y else y ).collect()
# Out:
# Out[67]: [('The Shawshank Redemption', 5),
#  ('12 Angry Men', 4),
#  ('The Godfather', 5),
#  ('The Matrix', 5),
#  ('Pulp Fiction', 5)]
