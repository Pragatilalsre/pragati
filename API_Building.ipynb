# %%
pip install Flask
# Out:
# Python interpreter will be restarted.
# ...
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Not uninstalling markupsafe at /databricks/python3/lib/python3.8/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-77e34b35-6600-449c-8a77-83f66703000b
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Not uninstalling jinja2 at /databricks/python3/lib/python3.8/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-77e34b35-6600-449c-8a77-83f66703000b
#     Can't uninstall 'Jinja2'. No files were found to uninstall.
# ...
# Python interpreter will be restarted.

# %%
pip install flask_restful
# Out:
# Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.

# %%
import flask
from flask import Flask
from flask_restful import Resource, Api, reqparse
import pandas as pd
import ast

# %%
pip install dash
# Out:
# Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.

# %%
import dash

# %%
app =Flask(name)
api = Api(app)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <command-426012545976549> in <module>
# ----> 1 app =Flask(name)
#       2 api = Api(app)
#
# NameError: name 'Flask' is not defined
